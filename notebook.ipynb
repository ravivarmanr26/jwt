# %%
from datetime import datetime,timedelta,timezone

# %%
userdatabase ={
    'stevejobs' : '12345',
    'billgates' : '12345',
    'mark zuckerberg': '32423'
}

# %%
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InN0ZXZlam9icyIsImV4cCI6MTc2NDMyNDkyMC44NTU2fQ.plLsnvDoLhFYzm-PyoHK8luATTzgWqFYEH7xZJb3VKk"

payload = token.split(".")[0]
payload
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9'

# %%
time = timedelta(minutes=10)
time
# Out:
# datetime.timedelta(seconds=600)

# %%
sessiontime = 50
exp_time = datetime.now() + timedelta(minutes=sessiontime)
print("current time ",datetime.now())
print("expire time",exp_time)
# Out:
# current time  2025-11-28 10:42:19.678815
# expire time 2025-11-28 11:32:19.678794

# %%
time = datetime.now(tz=timezone.utc) + timedelta(minutes=10)
t = time.timestamp()
print(t)
# Out:
# 1764305395.606192

# %%
username = 'stevejobs'
password ='12345'
if username in userdatabase and  userdatabase[username] == password:
    print(userdatabase[username])
    print("hello")
else:
    print("fuck not found")
# Out:
# 12345
# hello

# %% [markdown]
# jwt is json web token
# it is token is used to validate the user

# %%
import jwt
